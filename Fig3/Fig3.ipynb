# %% [markdown]
# ## Figure 3
# This Jupter Notebook plots Fig3: **Theoretical Result Verified by Stochastic Simulation and Finite State Projection** from the data we have computed and stored in `.npy` files. Data of SSA is computed using our `SSA.ipynb`; data of FSP is computed using our `FSP.ipynb`; data of analytical result in the article is computed using `Main.ipynb`.

# %%
# Visualization of results
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
print("SSAa shape:", np.load('fig3_SSA_a.npy').shape)
print("SSAb shape:", np.load('fig3_SSA_b.npy').shape)
print("SSAc shape:", np.load('fig3_SSA_c.npy').shape)
print("SSAd shape:", np.load('fig3_SSA_d.npy').shape)
print("FSPa shape:", np.load('fig3_FSP_a.npy').shape)
print("FSPb shape:", np.load('fig3_FSP_b.npy').shape)
print("FSPc shape:", np.load('fig3_FSP_c.npy').shape)
print("FSPd shape:", np.load('fig3_FSP_d.npy').shape)
print("Maina shape:", np.load('fig3_MAIN_a.npy').shape)
print("Mainb shape:", np.load('fig3_MAIN_b.npy').shape)
print("Mainc shape:", np.load('fig3_MAIN_c.npy').shape)
print("Maind shape:", np.load('fig3_MAIN_d.npy').shape)
# Out:
# SSAa shape: (100000,)
# SSAb shape: (100000,)
# SSAc shape: (100000,)
# SSAd shape: (100000,)
# FSPa shape: (41,)
# FSPb shape: (41,)
# FSPc shape: (31,)
# FSPd shape: (31,)
# Maina shape: (41,)
# Mainb shape: (41,)
# Mainc shape: (31,)
# Maind shape: (31,)

# %%
SSAa=np.load('fig3_SSA_a.npy').tolist()
SSAb=np.load('fig3_SSA_b.npy').tolist()
SSAc=np.load('fig3_SSA_c.npy').tolist()
SSAd=np.load('fig3_SSA_d.npy').tolist()
FSPa=np.load('fig3_FSP_a.npy').tolist()
FSPb=np.load('fig3_FSP_b.npy').tolist()
FSPc=np.load('fig3_FSP_c.npy').tolist()
FSPd=np.load('fig3_FSP_d.npy').tolist()
Maina=np.load('fig3_MAIN_a.npy').tolist()
Mainb=np.load('fig3_MAIN_b.npy').tolist()
Mainc=np.load('fig3_MAIN_c.npy').tolist()
Maind=np.load('fig3_MAIN_d.npy').tolist()

# %%
fig, axs = plt.subplots(2,2, figsize=(6.5,4))

ax1=axs[0,0]
ax2=axs[0,1]
ax3=axs[1,0]
ax4=axs[1,1]

dim1=list(range(41))
dim2=list(range(41))
dim3=list(range(31))
dim4=list(range(31))

plt.style.use('default')
# plt.style.use('ggplot')
plt.rcParams['axes.linewidth'] = 3

fig.suptitle(f'Theoretical Result Verified by Stochastic Simulation and Finite State Projection',
          fontname='Times New Roman', fontsize=12, fontweight='bold', color='green')


# ******************************************************************************************************
# ******************************************************************************************************
markerline1, stemlines1, baseline1 = ax1.stem(dim1, Maina[0:41],
                                           linefmt='r--', 
                                           markerfmt='bo', 
                                           basefmt="", 
                                           label='Theoretical Result')
plt.setp(markerline1, markersize=5)
plt.setp(stemlines1, linewidth=0.5)
plt.setp(baseline1, visible=False)  

sns.lineplot(x=dim1, y=FSPa[0:41], ax=ax1, label='FSP', color='#FF6347',
             linestyle='-', marker='v', markerfacecolor='#20B2AA',
             markersize=5, linewidth=2,alpha=0.7)

ax1.hist(SSAa, bins=np.arange(-0.5, max(SSAa)+0.5, 1), density=True, 
         color='#228B22', edgecolor='green', alpha=0.1,
         linewidth=2, align='mid', label='SSA')

# ax1.set_title('Theoretical Result Verified by Stochastic Simulation and Finite State Projection', 
#               fontname='Times New Roman', fontsize=40, 
#               fontweight='bold', color='green')
# ax1.set_xlabel('Number of mRNA Molecules', fontsize=35, fontweight='bold',
#                labelpad=20, fontname='Times New Roman', color='green')
ax1.set_ylabel('Probability', fontsize=10, fontweight='bold',
               labelpad=3, fontname='Times New Roman', color='green')

lines1, labels1 = ax1.get_legend_handles_labels()
legend1 = ax1.legend(lines1, labels1, loc='upper right',
                    frameon=True, shadow=True, markerscale=1,
                    fancybox=True, prop={'family': 'Times New Roman', 'size': 7})
legend1.get_frame().set_color('#E6E6FA')
legend1.get_frame().set_alpha(0.8)
# ax1.grid(True, which='both', linestyle='-', linewidth=1, alpha=0.3)
ax1.grid(False)

ticks_x1 = list(range(0, 45, 5))
ax1.set_xticks(ticks_x1)
ax1.set_xticklabels(ticks_x1,
                    fontname='Times New Roman',
                    fontsize=10,
                    color='blue',
                    ha='right')

ticks_y1 = np.arange(0, 0.09, 0.02)
ax1.set_yticks(ticks_y1)
ax1.set_yticklabels(ticks_y1,
                    fontname='Times New Roman',
                    fontsize=10,
                    color='blue',
                    ha='right',
                    rotation=90)

ax1.tick_params(direction='out', width=1, length=5)
ax1.set_frame_on(False)
# ******************************************************************************************************
# ******************************************************************************************************
markerline2, stemlines2, baseline2 = ax2.stem(dim2, Mainb[0:41],
                                           linefmt='r--', 
                                           markerfmt='bo', 
                                           basefmt="", 
                                           label='Theoretical Result')
plt.setp(markerline2, markersize=5)
plt.setp(stemlines2, linewidth=0.5)
plt.setp(baseline2, visible=False)  

sns.lineplot(x=dim2, y=FSPb[0:41], ax=ax2, label='FSP', color='#FF6347',
             linestyle='-', marker='v', markerfacecolor='#20B2AA',
             markersize=5, linewidth=2,alpha=0.7)

ax2.hist(SSAb, bins=np.arange(-0.5, max(SSAb)+0.5, 1), density=True, 
         color='#228B22', edgecolor='green', alpha=0.1,
         linewidth=2, align='mid', label='SSA')

# ax2.set_title('Theoretical Result Verified by Stochastic Simulation and Finite State Projection', 
#               fontname='Times New Roman', fontsize=40, 
#               fontweight='bold', color='green')
# ax2.set_xlabel('Number of mRNA Molecules', fontsize=35, fontweight='bold',
#                labelpad=20, fontname='Times New Roman', color='green')
# ax2.set_ylabel('Probability', fontsize=35, fontweight='bold',
#                labelpad=30, fontname='Times New Roman', color='green')

lines2, labels2 = ax2.get_legend_handles_labels()
legend2 = ax2.legend(lines2, labels2, loc='upper right',
                    frameon=True, shadow=True, markerscale=1,
                    fancybox=True, prop={'family': 'Times New Roman', 'size': 7})
legend2.get_frame().set_color('#E6E6FA')
legend2.get_frame().set_alpha(0.8)
# ax2.grid(True, which='both', linestyle='-', linewidth=2, alpha=0.3)
ax2.grid(False)

ticks_x2 = list(range(0, 45, 5))
ax2.set_xticks(ticks_x2)
ax2.set_xticklabels(ticks_x2,
                    fontname='Times New Roman',
                    fontsize=10,
                    color='blue',
                    ha='right')

ticks_y2 = np.arange(0, 0.1, 0.02)
ax2.set_yticks(ticks_y2)
ax2.set_yticklabels(ticks_y2,
                    fontname='Times New Roman',
                    fontsize=10,
                    color='blue',
                    ha='right',
                    rotation=90)

ax2.tick_params(direction='out', width=1, length=5)
ax2.set_frame_on(False)
# ******************************************************************************************************
# ******************************************************************************************************
markerline3, stemlines3, baseline3 = ax3.stem(dim3, Mainc[0:31],
                                           linefmt='r--', 
                                           markerfmt='bo', 
                                           basefmt="", 
                                           label='Theoretical Result')
plt.setp(markerline3, markersize=5)
plt.setp(stemlines3, linewidth=0.5)
plt.setp(baseline3, visible=False)  

sns.lineplot(x=dim3, y=FSPc[0:31], ax=ax3, label='FSP', color='#FF6347',
             linestyle='-', marker='v', markerfacecolor='#20B2AA',
             markersize=5, linewidth=2,alpha=0.7)

ax3.hist(SSAc, bins=np.arange(-0.5, max(SSAc)+0.5, 1), density=True, 
         color='#228B22', edgecolor='green', alpha=0.1,
         linewidth=2, align='mid', label='SSA')

# ax3.set_title('Theoretical Result Verified by Stochastic Simulation and Finite State Projection', 
#               fontname='Times New Roman', fontsize=40, 
#               fontweight='bold', color='green')
ax3.set_xlabel('Number of mRNA Molecules', fontsize=10, fontweight='bold',
               labelpad=3, fontname='Times New Roman', color='green')
ax3.set_ylabel('Probability', fontsize=10, fontweight='bold',
               labelpad=3, fontname='Times New Roman', color='green')

lines3, labels3 = ax3.get_legend_handles_labels()
legend3 = ax3.legend(lines3, labels3, loc='upper right',
                    frameon=True, shadow=True, markerscale=1,
                    fancybox=True, prop={'family': 'Times New Roman', 'size': 7})
legend3.get_frame().set_color('#E6E6FA')
legend3.get_frame().set_alpha(0.8)
# ax3.grid(True, which='both', linestyle='-', linewidth=2, alpha=0.3)
ax3.grid(False)

ticks_x3 = list(range(0, 35, 5))
ax3.set_xticks(ticks_x3)
ax3.set_xticklabels(ticks_x3,
                    fontname='Times New Roman',
                    fontsize=10,
                    color='blue',
                    ha='right')

ticks_y3 = np.arange(0, 0.2, 0.04)
ax3.set_yticks(ticks_y3)
ax3.set_yticklabels(ticks_y3,
                    fontname='Times New Roman',
                    fontsize=10,
                    color='blue',
                    ha='right',
                    rotation=90)

ax3.tick_params(direction='out', width=1, length=5)
ax3.set_frame_on(False)
# ******************************************************************************************************
# ******************************************************************************************************
markerline4, stemlines4, baseline4 = ax4.stem(dim4, Maind[0:31],
                                           linefmt='r--', 
                                           markerfmt='bo', 
                                           basefmt="", 
                                           label='Theoretical Result')
plt.setp(markerline4, markersize=5)
plt.setp(stemlines4, linewidth=0.5)
plt.setp(baseline4, visible=False)  

sns.lineplot(x=dim4, y=FSPd[0:31], ax=ax4, label='FSP', color='#FF6347',
             linestyle='-', marker='v', markerfacecolor='#20B2AA',
             markersize=5, linewidth=2,alpha=0.7)

ax4.hist(SSAd, bins=np.arange(-0.5, max(SSAd)+0.5, 1), density=True, 
         color='#228B22', edgecolor='green', alpha=0.1,
         linewidth=2, align='mid', label='SSA')

# ax3.set_title('Theoretical Result Verified by Stochastic Simulation and Finite State Projection', 
#               fontname='Times New Roman', fontsize=40, 
#               fontweight='bold', color='green')
ax4.set_xlabel('Number of mRNA Molecules', fontsize=10, fontweight='bold',
               labelpad=3, fontname='Times New Roman', color='green')
# ax3.set_ylabel('Probability', fontsize=40, fontweight='bold',
#                labelpad=30, fontname='Times New Roman', color='green')

lines4, labels4 = ax4.get_legend_handles_labels()
legend4 = ax4.legend(lines4, labels4, loc='upper right',
                    frameon=True, shadow=True, markerscale=1,
                    fancybox=True, prop={'family': 'Times New Roman', 'size': 7})
legend4.get_frame().set_color('#E6E6FA')
legend4.get_frame().set_alpha(0.8)
# ax4.grid(True, which='both', linestyle='-', linewidth=2, alpha=0.3)
ax4.grid(False)

ticks_x4 = list(range(0, 35, 5))
ax4.set_xticks(ticks_x4)
ax4.set_xticklabels(ticks_x4,
                    fontname='Times New Roman',
                    fontsize=10,
                    color='blue',
                    ha='right')

ticks_y4 = np.arange(0, 0.2, 0.04)
ax4.set_yticks(ticks_y4)
ax4.set_yticklabels(ticks_y4,
                    fontname='Times New Roman',
                    fontsize=10,
                    color='blue',
                    ha='right',
                    rotation=90)

ax4.tick_params(direction='out', width=1, length=5)
ax4.set_frame_on(False)

plt.savefig('Fig3.pdf', format='pdf',edgecolor='black', dpi=300)
plt.show()

# %%
fig, axs = plt.subplots(2,2, figsize=(36,24))
# fig, axs = plt.subplots(2,2, figsize=(18,12))
ax1=axs[0,0]
ax2=axs[0,1]
ax3=axs[1,0]
ax4=axs[1,1]

dim1=list(range(41))
dim2=list(range(41))
dim3=list(range(31))
dim4=list(range(31))

plt.style.use('default')
# plt.style.use('ggplot')
plt.rcParams['axes.linewidth'] = 3

fig.suptitle(f'Theoretical Result Verified by Stochastic Simulation and Finite State Projection',
          fontname='Times New Roman', fontsize=55, fontweight='bold', color='green')  # 60 -> 55

# ******************************************************************************************************
# ******************************************************************************************************
markerline1, stemlines1, baseline1 = ax1.stem(dim1, Maina[0:41],
                                           linefmt='r--', 
                                           markerfmt='bo', 
                                           basefmt="", 
                                           label='Theoretical Result')
plt.setp(markerline1, markersize=25)
plt.setp(stemlines1, linewidth=1)
plt.setp(baseline1, visible=False)  

sns.lineplot(x=dim1, y=FSPa[0:41], ax=ax1, label='FSP', color='#FF6347',
             linestyle='-', marker='v', markerfacecolor='#20B2AA',
             markersize=30, linewidth=6,alpha=0.7)

ax1.hist(SSAa, bins=np.arange(-0.5, max(SSAa)+0.5, 1), density=True, 
         color='#228B22', edgecolor='green', alpha=0.3,
         linewidth=2, align='mid', label='SSA')

# ax1.set_title('Theoretical Result Verified by Stochastic Simulation and Finite State Projection', 
#               fontname='Times New Roman', fontsize=40, 
#               fontweight='bold', color='green')
# ax1.set_xlabel('Number of mRNA Molecules', fontsize=35, fontweight='bold',
#                labelpad=20, fontname='Times New Roman', color='green')
ax1.set_ylabel('Probability', fontsize=45, fontweight='bold',   # 40 -> 45
               labelpad=30, fontname='Times New Roman', color='green')

lines1, labels1 = ax1.get_legend_handles_labels()
legend1 = ax1.legend(lines1, labels1, loc='upper right',
                    frameon=True, shadow=True, markerscale=1,
                    fancybox=True, prop={'family': 'Times New Roman', 'size': 30})
legend1.get_frame().set_color('#E6E6FA')
legend1.get_frame().set_alpha(0.8)
ax1.grid(True, which='both', linestyle='-', linewidth=2, alpha=0.3) 

ticks_x1 = list(range(0, 45, 5))
ax1.set_xticks(ticks_x1)
ax1.set_xticklabels(ticks_x1,
                    fontname='Times New Roman',
                    fontsize=30,   # 40 -> 30
                    color='blue',
                    ha='right')

ticks_y1 = np.arange(0, 0.09, 0.02)
ax1.set_yticks(ticks_y1)
ax1.set_yticklabels(ticks_y1,
                    fontname='Times New Roman',
                    fontsize=30,   # 40 -> 30
                    color='blue',
                    ha='right',
                    rotation=90)

ax1.tick_params(direction='out', width=3, length=10)

# ******************************************************************************************************
# ******************************************************************************************************
markerline2, stemlines2, baseline2 = ax2.stem(dim2, Mainb[0:41],
                                           linefmt='r--', 
                                           markerfmt='bo', 
                                           basefmt="", 
                                           label='Theoretical Result')
plt.setp(markerline2, markersize=25)
plt.setp(stemlines2, linewidth=1)
plt.setp(baseline2, visible=False)  

sns.lineplot(x=dim2, y=FSPb[0:41], ax=ax2, label='FSP', color='#FF6347',
             linestyle='-', marker='v', markerfacecolor='#20B2AA',
             markersize=30, linewidth=6,alpha=0.7)

ax2.hist(SSAb, bins=np.arange(-0.5, max(SSAb)+0.5, 1), density=True, 
         color='#228B22', edgecolor='green', alpha=0.3,
         linewidth=2, align='mid', label='SSA')

# ax2.set_title('Theoretical Result Verified by Stochastic Simulation and Finite State Projection', 
#               fontname='Times New Roman', fontsize=40, 
#               fontweight='bold', color='green')
# ax2.set_xlabel('Number of mRNA Molecules', fontsize=35, fontweight='bold',
#                labelpad=20, fontname='Times New Roman', color='green')
# ax2.set_ylabel('Probability', fontsize=35, fontweight='bold',
#                labelpad=30, fontname='Times New Roman', color='green')

lines2, labels2 = ax2.get_legend_handles_labels()
legend2 = ax2.legend(lines2, labels2, loc='upper right',
                    frameon=True, shadow=True, markerscale=1,
                    fancybox=True, prop={'family': 'Times New Roman', 'size': 30})
legend2.get_frame().set_color('#E6E6FA')
legend2.get_frame().set_alpha(0.8)
ax2.grid(True, which='both', linestyle='-', linewidth=2, alpha=0.3) 

ticks_x2 = list(range(0, 45, 5))
ax2.set_xticks(ticks_x2)
ax2.set_xticklabels(ticks_x2,
                    fontname='Times New Roman',
                    fontsize=30,   # 40 -> 30
                    color='blue',
                    ha='right')

ticks_y2 = np.arange(0, 0.1, 0.02)
ax2.set_yticks(ticks_y2)
ax2.set_yticklabels(ticks_y2,
                    fontname='Times New Roman',
                    fontsize=30,   # 40 -> 30
                    color='blue',
                    ha='right',
                    rotation=90)

ax2.tick_params(direction='out', width=3, length=10)

# ******************************************************************************************************
# ******************************************************************************************************
markerline3, stemlines3, baseline3 = ax3.stem(dim3, Mainc[0:31],
                                           linefmt='r--', 
                                           markerfmt='bo', 
                                           basefmt="", 
                                           label='Theoretical Result')
plt.setp(markerline3, markersize=25)
plt.setp(stemlines3, linewidth=1)
plt.setp(baseline3, visible=False)  

sns.lineplot(x=dim3, y=FSPc[0:31], ax=ax3, label='FSP', color='#FF6347',
             linestyle='-', marker='v', markerfacecolor='#20B2AA',
             markersize=30, linewidth=6,alpha=0.7)

ax3.hist(SSAc, bins=np.arange(-0.5, max(SSAc)+0.5, 1), density=True, 
         color='#228B22', edgecolor='green', alpha=0.3,
         linewidth=2, align='mid', label='SSA')

# ax3.set_title('Theoretical Result Verified by Stochastic Simulation and Finite State Projection', 
#               fontname='Times New Roman', fontsize=40, 
#               fontweight='bold', color='green')
ax3.set_xlabel('Number of mRNA Molecules', fontsize=45, fontweight='bold',  # 40 -> 45
               labelpad=20, fontname='Times New Roman', color='green')
ax3.set_ylabel('Probability', fontsize=45, fontweight='bold',               # 40 -> 45
               labelpad=30, fontname='Times New Roman', color='green')

lines3, labels3 = ax3.get_legend_handles_labels()
legend3 = ax3.legend(lines3, labels3, loc='upper right',
                    frameon=True, shadow=True, markerscale=1,
                    fancybox=True, prop={'family': 'Times New Roman', 'size': 30})
legend3.get_frame().set_color('#E6E6FA')
legend3.get_frame().set_alpha(0.8)
ax3.grid(True, which='both', linestyle='-', linewidth=2, alpha=0.3) 

ticks_x3 = list(range(0, 35, 5))
ax3.set_xticks(ticks_x3)
ax3.set_xticklabels(ticks_x3,
                    fontname='Times New Roman',
                    fontsize=30,   # 40 -> 30
                    color='blue',
                    ha='right')

ticks_y3 = np.arange(0, 0.2, 0.04)
ax3.set_yticks(ticks_y3)
ax3.set_yticklabels(ticks_y3,
                    fontname='Times New Roman',
                    fontsize=30,   # 40 -> 30
                    color='blue',
                    ha='right',
                    rotation=90)

ax3.tick_params(direction='out', width=3, length=10)

# ******************************************************************************************************
# ******************************************************************************************************
markerline4, stemlines4, baseline4 = ax4.stem(dim4, Maind[0:31],
                                           linefmt='r--', 
                                           markerfmt='bo', 
                                           basefmt="", 
                                           label='Theoretical Result')
plt.setp(markerline4, markersize=25)
plt.setp(stemlines4, linewidth=1)
plt.setp(baseline4, visible=False)  

sns.lineplot(x=dim4, y=FSPd[0:31], ax=ax4, label='FSP', color='#FF6347',
             linestyle='-', marker='v', markerfacecolor='#20B2AA',
             markersize=30, linewidth=6,alpha=0.7)

ax4.hist(SSAd, bins=np.arange(-0.5, max(SSAd)+0.5, 1), density=True, 
         color='#228B22', edgecolor='green', alpha=0.3,
         linewidth=2, align='mid', label='SSA')

# ax3.set_title('Theoretical Result Verified by Stochastic Simulation and Finite State Projection', 
#               fontname='Times New Roman', fontsize=40, 
#               fontweight='bold', color='green')
ax4.set_xlabel('Number of mRNA Molecules', fontsize=45, fontweight='bold',  # 40 -> 45
               labelpad=20, fontname='Times New Roman', color='green')
# ax3.set_ylabel('Probability', fontsize=40, fontweight='bold',
#                labelpad=30, fontname='Times New Roman', color='green')

lines4, labels4 = ax4.get_legend_handles_labels()
legend4 = ax4.legend(lines4, labels4, loc='upper right',
                    frameon=True, shadow=True, markerscale=1,
                    fancybox=True, prop={'family': 'Times New Roman', 'size': 30})
legend4.get_frame().set_color('#E6E6FA')
legend4.get_frame().set_alpha(0.8)
ax4.grid(True, which='both', linestyle='-', linewidth=2, alpha=0.3) 

ticks_x4 = list(range(0, 35, 5))
ax4.set_xticks(ticks_x4)
ax4.set_xticklabels(ticks_x4,
                    fontname='Times New Roman',
                    fontsize=30,   # 40 -> 30
                    color='blue',
                    ha='right')

ticks_y4 = np.arange(0, 0.2, 0.04)
ax4.set_yticks(ticks_y4)
ax4.set_yticklabels(ticks_y4,
                    fontname='Times New Roman',
                    fontsize=30,   # 40 -> 30
                    color='blue',
                    ha='right',
                    rotation=90)

ax4.tick_params(direction='out', width=3, length=10)

plt.savefig('Fig3_New.pdf', format='pdf',edgecolor='black', dpi=800)
plt.show()
