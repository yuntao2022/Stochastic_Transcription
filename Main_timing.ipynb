# %% [markdown]
# ## **Computing Binomial Moments using Eq.(8)**
#
# **Stochastic Kinetics of mRNA Molecules in a General Transcription Model**
#
# *Yuntao Lu and Yunxin Zhang*
#
# School of Mathematical Sciences, Fudan University, Shanghai 200433, China
#
# Email: `yuntaolu22@m.fudan.edu.cn` and `xyz@fudan.edu.cn`
#
# This script is written to time computations using Eq.(8), generating date used to plot Figure 4.

# %%
import scipy.linalg as linalg
import numpy as np
import time
import math

# %%
def moment(D0, D1, M=200, threshold=1e-32):
    """
    Compute the first M+1 binomial moments (starting from B_0=1) of mRNA copy number 
    with given parameters in the transcription model (1) in our manucript.
  
    Input:
    D0 (np.ndarray): Transition rate matrix for non-transcription events
    D1 (np.ndarray): Transition rate matrix for transcription events
    M (int): Number of binomial moments to compute (returns M+1 moments including B_0)
    threshold (float, optional): Tolerance used for determining early stop. If the value of
                                 binomial moment is below this threshold, the computation is terminated.
                                 Default is 1e-32.
    
    Output:
    list: Binomial moments [B_0, B_1, ..., B_M] where B0=1 by definition
    
    Raises:
    TypeError: If input types are incorrect
    ValueError: If matrices are invalid or dimensions mismatch
    RuntimeError: For numerical computation errors
    """
    # ==============================================
    # INPUT VALIDATION AND SAFETY CHECKS
    # ==============================================
    
    # Type checking for input parameters
    if not isinstance(D0, np.ndarray) or not isinstance(D1, np.ndarray):
        raise TypeError("Input matrices D0 and D1 must be NumPy arrays")
    if not isinstance(M, int):
        raise TypeError("M must be an integer")
    
    # Matrix dimension validation
    if D0.ndim != 2 or D1.ndim != 2:
        raise ValueError("Input matrices must be 2-dimensional arrays")
    
    n0, m0 = D0.shape
    n1, m1 = D1.shape
    
    # Check if matrices are square
    if n0 != m0:
        raise ValueError("D0 must be a square matrix")
    if n1 != m1:
        raise ValueError("D1 must be a square matrix")
    
    # Check matrix dimension consistency
    if n0 != n1:
        raise ValueError("D0 and D1 must have the same dimension")
    n = n0  # Dimension of the system
    
    # Validate moment count
    if M < 0:
        raise ValueError("M must be a non-negative integer")
    
    # Hydrolysis rate (normalized to 1)
    d = 1.0  

    
    # Construct Q-matrix D
    D = D0 + D1
    
    # ==============================================
    # Q-MATRIX VALIDATION
    # ==============================================
    tol = 1e-8  # Numerical tolerance for checks
    
    # Validate Q-matrix properties:
    # 1. Row sums should be zero (within tolerance)
    row_sums = np.sum(D, axis=1)
    if not np.allclose(row_sums, 0, atol=tol):
        max_error = np.max(np.abs(row_sums))
        raise ValueError(f"Invalid generator matrix: Row sums should be zero "
                         f"(max error: {max_error:.2e})")
    
    # 2. Off-diagonal elements should be non-negative
    D_offdiag = D.copy()
    np.fill_diagonal(D_offdiag, 0)
    if np.any(D_offdiag < -tol):
        min_value = np.min(D_offdiag)
        raise ValueError(f"Invalid generator matrix: Negative off-diagonals "
                         f"(min value: {min_value:.2e})")
    
    # 3. Diagonal elements should be non-positive
    diag_elements = np.diag(D)
    if np.any(diag_elements > tol):
        max_value = np.max(diag_elements)
        raise ValueError(f"Invalid generator matrix: Positive diagonals "
                         f"(max value: {max_value:.2e})")
    
    # Check numerical stability
    # inf_norm_D1 = linalg.norm(D1, np.inf)
    # if inf_norm_D1 > 9:
        # print(f"Warning: High matrix norm ||D1||_∞ = {inf_norm_D1:.2f} - "
               # "potential numerical instability")
    
    # ==============================================
    # COMPUTATION of Invariant Distribution of D
    # ==============================================
    try:
        # Construct linear system to calculate stationary distribution of the underlying Markov chain characterized by D:
        # D^T π = 0 with constraint sum(π) = 1
        DT = D.T.copy()
        
        # Replace first row with constraint equation
        DT[0, :] = np.ones(n)
        
        # Right-hand side vector: [1, 0, 0, ...]
        b = np.zeros(n)
        b[0] = 1.0
        
        # Check matrix condition number
        cond_num = np.linalg.cond(DT)
        if cond_num > 1e12:
            print(f"Warning: Ill-conditioned matrix (cond={cond_num:.2e})")
        
        # Solve for stationary distribution pi (pi is a 2D NumPy array of shape (1, n))
        pi = np.linalg.solve(DT, b).reshape(1, n)
    
    except np.linalg.LinAlgError as e:
        print(f"Linear system solver failed: {str(e)}.")
        print(f'Make sure that the Q-matrix D is irreducible.')
        raise
    
    # Vector of ones (e is a 2D NumPy array of shape (n, 1))
    e = np.ones((n, 1))
    
    # ==============================================
    # BINOMIAL MOMENTS COMPUTATION
    # ==============================================
    
    
    binomial_moments = [1.0]  # strat with B_0 = 1
    
    # Early return for trivial case
    if M == 0:
        return binomial_moments
    
    # ==============================================
    # Start timing the computation
    start_time = time.time()
    # ==============================================
    
    # Compute first moment B1
    B1 = (pi @ D1 @ e) / d
    binomial_moments.append(float(B1[0, 0]))
    
    
    # Compute higher-order moments (B2 to BM)
    if M > 1:
        B_vec = pi @ D1  # Initialize moment vector
    
        index_at_threshold = None
        
        for i in range(2, M + 1):
            # Construct matrix for current iteration
            A = (i - 1) * d * np.eye(n) - D
            
            # Compute the inverse of (i-1)*d*I - D using scipy.linalg.inv()    
            invA = linalg.inv(A)
    
            # Compute next vector: B_vec = B_vec * inv(A) * D1
            B_vec = B_vec @ invA @ D1
            moment_i = (B_vec @ e) / (i * d)
            moment_val = float(moment_i[0, 0])
            
            # Store computed moment
            binomial_moments.append(moment_val)
            
            # Early termination if moments become negligible
            # if moment_val < threshold:
            #     if index_at_threshold is None:
            #         index_at_threshold = i
            #         print(f"Moments below threshold at i={i}")
            #         break
    
    # ==============================================
    # FINAL VALIDATION AND OUTPUT
    # ==============================================
    # Verify we computed the correct number of moments
    # if len(binomial_moments) != M + 1:
    #     print(f"Expected {M+1} moments, got {len(binomial_moments)}. ")
    #     print(f'\nEarly stop due to threshold={threshold}')
    
    # Print performance statistics
    total_time = time.time() - start_time
    print(f"Computation for {n0}-th order model is completed in {total_time:.4f} seconds")
    # print(f"\nComputed {len(binomial_moments)} binomial moments")
    
    return total_time,binomial_moments

# %%
# import parameter matrices prepared for figures in the paper
import Parameters_for_Figures

# %%
times=[]
for i in range(1,201):
    time1=moment(Parameters_for_Figures.generate_D0n(i),
                     Parameters_for_Figures.generate_D1n(i),
                 200)[0]
    time2=moment(Parameters_for_Figures.generate_D0n(i),
                     Parameters_for_Figures.generate_D1n(i),
                 200)[0]
    time3=moment(Parameters_for_Figures.generate_D0n(i),
                     Parameters_for_Figures.generate_D1n(i),
                 200)[0]
    times.append(float(np.average([time1,time2,time3])))
# Out:
# Computation for 1-th order model is completed in 0.0243 seconds
# Computation for 1-th order model is completed in 0.0151 seconds
# Computation for 1-th order model is completed in 0.0130 seconds
# Computation for 2-th order model is completed in 0.0125 seconds
# Computation for 2-th order model is completed in 0.0109 seconds
# Computation for 2-th order model is completed in 0.0093 seconds
# Computation for 3-th order model is completed in 0.0082 seconds
# Computation for 3-th order model is completed in 0.0074 seconds
# Computation for 3-th order model is completed in 0.0070 seconds
# Computation for 4-th order model is completed in 0.0064 seconds
# Computation for 4-th order model is completed in 0.0063 seconds
# Computation for 4-th order model is completed in 0.0060 seconds
# Computation for 5-th order model is completed in 0.0060 seconds
# Computation for 5-th order model is completed in 0.0056 seconds
# Computation for 5-th order model is completed in 0.0056 seconds
# ...

# %% [raw]
# Computation for 1-th order model is completed in 0.0243 seconds
# Computation for 1-th order model is completed in 0.0151 seconds
# Computation for 1-th order model is completed in 0.0130 seconds
# Computation for 2-th order model is completed in 0.0125 seconds
# Computation for 2-th order model is completed in 0.0109 seconds
# Computation for 2-th order model is completed in 0.0093 seconds
# Computation for 3-th order model is completed in 0.0082 seconds
# Computation for 3-th order model is completed in 0.0074 seconds
# Computation for 3-th order model is completed in 0.0070 seconds
# Computation for 4-th order model is completed in 0.0064 seconds
# Computation for 4-th order model is completed in 0.0063 seconds
# Computation for 4-th order model is completed in 0.0060 seconds
# Computation for 5-th order model is completed in 0.0060 seconds
# Computation for 5-th order model is completed in 0.0056 seconds
# Computation for 5-th order model is completed in 0.0056 seconds
# Computation for 6-th order model is completed in 0.0054 seconds
# Computation for 6-th order model is completed in 0.0055 seconds
# Computation for 6-th order model is completed in 0.0055 seconds
# Computation for 7-th order model is completed in 0.0055 seconds
# Computation for 7-th order model is completed in 0.0055 seconds
# Computation for 7-th order model is completed in 0.0054 seconds
# Computation for 8-th order model is completed in 0.0056 seconds
# Computation for 8-th order model is completed in 0.0055 seconds
# Computation for 8-th order model is completed in 0.0055 seconds
# Computation for 9-th order model is completed in 0.0069 seconds
# Computation for 9-th order model is completed in 0.0059 seconds
# Computation for 9-th order model is completed in 0.0056 seconds
# Computation for 10-th order model is completed in 0.0057 seconds
# Computation for 10-th order model is completed in 0.0057 seconds
# Computation for 10-th order model is completed in 0.0086 seconds
# Computation for 11-th order model is completed in 0.0063 seconds
# Computation for 11-th order model is completed in 0.0067 seconds
# Computation for 11-th order model is completed in 0.0065 seconds
# Computation for 12-th order model is completed in 0.0070 seconds
# Computation for 12-th order model is completed in 0.0064 seconds
# Computation for 12-th order model is completed in 0.0069 seconds
# Computation for 13-th order model is completed in 0.0057 seconds
# Computation for 13-th order model is completed in 0.0056 seconds
# Computation for 13-th order model is completed in 0.0056 seconds
# Computation for 14-th order model is completed in 0.0058 seconds
# Computation for 14-th order model is completed in 0.0057 seconds
# Computation for 14-th order model is completed in 0.0057 seconds
# Computation for 15-th order model is completed in 0.0059 seconds
# Computation for 15-th order model is completed in 0.0059 seconds
# Computation for 15-th order model is completed in 0.0059 seconds
# Computation for 16-th order model is completed in 0.0059 seconds
# Computation for 16-th order model is completed in 0.0058 seconds
# Computation for 16-th order model is completed in 0.0059 seconds
# Computation for 17-th order model is completed in 0.0061 seconds
# Computation for 17-th order model is completed in 0.0061 seconds
# Computation for 17-th order model is completed in 0.0060 seconds
# Computation for 18-th order model is completed in 0.0063 seconds
# Computation for 18-th order model is completed in 0.0063 seconds
# Computation for 18-th order model is completed in 0.0062 seconds
# Computation for 19-th order model is completed in 0.0064 seconds
# Computation for 19-th order model is completed in 0.0064 seconds
# Computation for 19-th order model is completed in 0.0064 seconds
# Computation for 20-th order model is completed in 0.0064 seconds
# Computation for 20-th order model is completed in 0.0065 seconds
# Computation for 20-th order model is completed in 0.0064 seconds
# Computation for 21-th order model is completed in 0.0068 seconds
# Computation for 21-th order model is completed in 0.0068 seconds
# Computation for 21-th order model is completed in 0.0068 seconds
# Computation for 22-th order model is completed in 0.0069 seconds
# Computation for 22-th order model is completed in 0.0069 seconds
# Computation for 22-th order model is completed in 0.0069 seconds
# Computation for 23-th order model is completed in 0.0091 seconds
# Computation for 23-th order model is completed in 0.0076 seconds
# Computation for 23-th order model is completed in 0.0072 seconds
# Computation for 24-th order model is completed in 0.0073 seconds
# Computation for 24-th order model is completed in 0.0072 seconds
# Computation for 24-th order model is completed in 0.0072 seconds
# Computation for 25-th order model is completed in 0.0076 seconds
# Computation for 25-th order model is completed in 0.0076 seconds
# Computation for 25-th order model is completed in 0.0076 seconds
# Computation for 26-th order model is completed in 0.0078 seconds
# Computation for 26-th order model is completed in 0.0078 seconds
# Computation for 26-th order model is completed in 0.0077 seconds
# Computation for 27-th order model is completed in 0.0081 seconds
# Computation for 27-th order model is completed in 0.0080 seconds
# Computation for 27-th order model is completed in 0.0081 seconds
# Computation for 28-th order model is completed in 0.0081 seconds
# Computation for 28-th order model is completed in 0.0080 seconds
# Computation for 28-th order model is completed in 0.0081 seconds
# Computation for 29-th order model is completed in 0.0084 seconds
# Computation for 29-th order model is completed in 0.0084 seconds
# Computation for 29-th order model is completed in 0.0084 seconds
# Computation for 30-th order model is completed in 0.0087 seconds
# Computation for 30-th order model is completed in 0.0087 seconds
# Computation for 30-th order model is completed in 0.0088 seconds
# Computation for 31-th order model is completed in 0.0091 seconds
# Computation for 31-th order model is completed in 0.0103 seconds
# Computation for 31-th order model is completed in 0.0094 seconds
# Computation for 32-th order model is completed in 0.0089 seconds
# Computation for 32-th order model is completed in 0.0089 seconds
# Computation for 32-th order model is completed in 0.0089 seconds
# Computation for 33-th order model is completed in 0.0094 seconds
# Computation for 33-th order model is completed in 0.0095 seconds
# Computation for 33-th order model is completed in 0.0094 seconds
# Computation for 34-th order model is completed in 0.0096 seconds
# Computation for 34-th order model is completed in 0.0096 seconds
# Computation for 34-th order model is completed in 0.0096 seconds
# Computation for 35-th order model is completed in 0.0101 seconds
# Computation for 35-th order model is completed in 0.0100 seconds
# Computation for 35-th order model is completed in 0.0100 seconds
# Computation for 36-th order model is completed in 0.0103 seconds
# Computation for 36-th order model is completed in 0.0102 seconds
# Computation for 36-th order model is completed in 0.0102 seconds
# Computation for 37-th order model is completed in 0.0108 seconds
# Computation for 37-th order model is completed in 0.0108 seconds
# Computation for 37-th order model is completed in 0.0108 seconds
# Computation for 38-th order model is completed in 0.0121 seconds
# Computation for 38-th order model is completed in 0.0113 seconds
# Computation for 38-th order model is completed in 0.0110 seconds
# Computation for 39-th order model is completed in 0.0114 seconds
# Computation for 39-th order model is completed in 0.0113 seconds
# Computation for 39-th order model is completed in 0.0114 seconds
# Computation for 40-th order model is completed in 0.0114 seconds
# Computation for 40-th order model is completed in 0.0114 seconds
# Computation for 40-th order model is completed in 0.0113 seconds
# Computation for 41-th order model is completed in 0.0122 seconds
# Computation for 41-th order model is completed in 0.0121 seconds
# Computation for 41-th order model is completed in 0.0120 seconds
# Computation for 42-th order model is completed in 0.0122 seconds
# Computation for 42-th order model is completed in 0.0122 seconds
# Computation for 42-th order model is completed in 0.0122 seconds
# Computation for 43-th order model is completed in 0.0128 seconds
# Computation for 43-th order model is completed in 0.0127 seconds
# Computation for 43-th order model is completed in 0.0140 seconds
# Computation for 44-th order model is completed in 0.0128 seconds
# Computation for 44-th order model is completed in 0.0128 seconds
# Computation for 44-th order model is completed in 0.0128 seconds
# Computation for 45-th order model is completed in 0.0136 seconds
# Computation for 45-th order model is completed in 0.0137 seconds
# Computation for 45-th order model is completed in 0.0136 seconds
# Computation for 46-th order model is completed in 0.0137 seconds
# Computation for 46-th order model is completed in 0.0136 seconds
# Computation for 46-th order model is completed in 0.0137 seconds
# Computation for 47-th order model is completed in 0.0143 seconds
# Computation for 47-th order model is completed in 0.0143 seconds
# Computation for 47-th order model is completed in 0.0142 seconds
# Computation for 48-th order model is completed in 0.0144 seconds
# Computation for 48-th order model is completed in 0.0143 seconds
# Computation for 48-th order model is completed in 0.0166 seconds
# Computation for 49-th order model is completed in 0.0158 seconds
# Computation for 49-th order model is completed in 0.0153 seconds
# Computation for 49-th order model is completed in 0.0153 seconds
# Computation for 50-th order model is completed in 0.0155 seconds
# Computation for 50-th order model is completed in 0.0154 seconds
# Computation for 50-th order model is completed in 0.0154 seconds
# Computation for 51-th order model is completed in 0.0162 seconds
# Computation for 51-th order model is completed in 0.0160 seconds
# Computation for 51-th order model is completed in 0.0160 seconds
# Computation for 52-th order model is completed in 0.0155 seconds
# Computation for 52-th order model is completed in 0.0156 seconds
# Computation for 52-th order model is completed in 0.0154 seconds
# Computation for 53-th order model is completed in 0.0183 seconds
# Computation for 53-th order model is completed in 0.0175 seconds
# Computation for 53-th order model is completed in 0.0172 seconds
# Computation for 54-th order model is completed in 0.0173 seconds
# Computation for 54-th order model is completed in 0.0171 seconds
# Computation for 54-th order model is completed in 0.0171 seconds
# Computation for 55-th order model is completed in 0.0180 seconds
# Computation for 55-th order model is completed in 0.0180 seconds
# Computation for 55-th order model is completed in 0.0181 seconds
# Computation for 56-th order model is completed in 0.0174 seconds
# Computation for 56-th order model is completed in 0.0173 seconds
# Computation for 56-th order model is completed in 0.0224 seconds
# Computation for 57-th order model is completed in 0.0194 seconds
# Computation for 57-th order model is completed in 0.0191 seconds
# Computation for 57-th order model is completed in 0.0192 seconds
# Computation for 58-th order model is completed in 0.0194 seconds
# Computation for 58-th order model is completed in 0.0193 seconds
# Computation for 58-th order model is completed in 0.0191 seconds
# Computation for 59-th order model is completed in 0.0201 seconds
# Computation for 59-th order model is completed in 0.0202 seconds
# Computation for 59-th order model is completed in 0.0201 seconds
# Computation for 60-th order model is completed in 0.0215 seconds
# Computation for 60-th order model is completed in 0.0204 seconds
# Computation for 60-th order model is completed in 0.0200 seconds
# Computation for 61-th order model is completed in 0.0216 seconds
# Computation for 61-th order model is completed in 0.0214 seconds
# Computation for 61-th order model is completed in 0.0214 seconds
# Computation for 62-th order model is completed in 0.0215 seconds
# Computation for 62-th order model is completed in 0.0214 seconds
# Computation for 62-th order model is completed in 0.0216 seconds
# Computation for 63-th order model is completed in 0.0225 seconds
# Computation for 63-th order model is completed in 0.0235 seconds
# Computation for 63-th order model is completed in 0.0223 seconds
# Computation for 64-th order model is completed in 0.0220 seconds
# Computation for 64-th order model is completed in 0.0218 seconds
# Computation for 64-th order model is completed in 0.0218 seconds
# Computation for 65-th order model is completed in 0.0631 seconds
# Computation for 65-th order model is completed in 0.0648 seconds
# Computation for 65-th order model is completed in 0.0644 seconds
# Computation for 66-th order model is completed in 0.0686 seconds
# Computation for 66-th order model is completed in 0.0799 seconds
# Computation for 66-th order model is completed in 0.0674 seconds
# Computation for 67-th order model is completed in 0.0540 seconds
# Computation for 67-th order model is completed in 0.0491 seconds
# Computation for 67-th order model is completed in 0.0464 seconds
# Computation for 68-th order model is completed in 0.0452 seconds
# Computation for 68-th order model is completed in 0.0451 seconds
# Computation for 68-th order model is completed in 0.0450 seconds
# Computation for 69-th order model is completed in 0.0457 seconds
# Computation for 69-th order model is completed in 0.0466 seconds
# Computation for 69-th order model is completed in 0.0460 seconds
# Computation for 70-th order model is completed in 0.0461 seconds
# Computation for 70-th order model is completed in 0.0502 seconds
# Computation for 70-th order model is completed in 0.0457 seconds
# Computation for 71-th order model is completed in 0.0485 seconds
# Computation for 71-th order model is completed in 0.0482 seconds
# Computation for 71-th order model is completed in 0.0539 seconds
# Computation for 72-th order model is completed in 0.0504 seconds
# Computation for 72-th order model is completed in 0.0515 seconds
# Computation for 72-th order model is completed in 0.0506 seconds
# Computation for 73-th order model is completed in 0.0553 seconds
# Computation for 73-th order model is completed in 0.0512 seconds
# Computation for 73-th order model is completed in 0.0519 seconds
# Computation for 74-th order model is completed in 0.0509 seconds
# Computation for 74-th order model is completed in 0.0548 seconds
# Computation for 74-th order model is completed in 0.0509 seconds
# Computation for 75-th order model is completed in 0.0534 seconds
# Computation for 75-th order model is completed in 0.0568 seconds
# Computation for 75-th order model is completed in 0.0533 seconds
# Computation for 76-th order model is completed in 0.0531 seconds
# Computation for 76-th order model is completed in 0.0537 seconds
# Computation for 76-th order model is completed in 0.0533 seconds
# Computation for 77-th order model is completed in 0.0548 seconds
# Computation for 77-th order model is completed in 0.0547 seconds
# Computation for 77-th order model is completed in 0.0558 seconds
# Computation for 78-th order model is completed in 0.0556 seconds
# Computation for 78-th order model is completed in 0.0526 seconds
# Computation for 78-th order model is completed in 0.0464 seconds
# Computation for 79-th order model is completed in 0.0522 seconds
# Computation for 79-th order model is completed in 0.0484 seconds
# Computation for 79-th order model is completed in 0.0473 seconds
# Computation for 80-th order model is completed in 0.0494 seconds
# Computation for 80-th order model is completed in 0.0510 seconds
# Computation for 80-th order model is completed in 0.0512 seconds
# Computation for 81-th order model is completed in 0.0491 seconds
# Computation for 81-th order model is completed in 0.0496 seconds
# Computation for 81-th order model is completed in 0.0537 seconds
# Computation for 82-th order model is completed in 0.0508 seconds
# Computation for 82-th order model is completed in 0.0498 seconds
# Computation for 82-th order model is completed in 0.0489 seconds
# Computation for 83-th order model is completed in 0.0506 seconds
# Computation for 83-th order model is completed in 0.0521 seconds
# Computation for 83-th order model is completed in 0.0588 seconds
# Computation for 84-th order model is completed in 0.0508 seconds
# Computation for 84-th order model is completed in 0.0554 seconds
# Computation for 84-th order model is completed in 0.0637 seconds
# Computation for 85-th order model is completed in 0.0554 seconds
# Computation for 85-th order model is completed in 0.0572 seconds
# Computation for 85-th order model is completed in 0.0517 seconds
# Computation for 86-th order model is completed in 0.0533 seconds
# Computation for 86-th order model is completed in 0.0511 seconds
# Computation for 86-th order model is completed in 0.0500 seconds
# Computation for 87-th order model is completed in 0.0534 seconds
# Computation for 87-th order model is completed in 0.0591 seconds
# Computation for 87-th order model is completed in 0.0569 seconds
# Computation for 88-th order model is completed in 0.0558 seconds
# Computation for 88-th order model is completed in 0.0578 seconds
# Computation for 88-th order model is completed in 0.0562 seconds
# Computation for 89-th order model is completed in 0.0572 seconds
# Computation for 89-th order model is completed in 0.0566 seconds
# Computation for 89-th order model is completed in 0.0575 seconds
# Computation for 90-th order model is completed in 0.0635 seconds
# Computation for 90-th order model is completed in 0.0574 seconds
# Computation for 90-th order model is completed in 0.0590 seconds
# Computation for 91-th order model is completed in 0.0594 seconds
# Computation for 91-th order model is completed in 0.0649 seconds
# Computation for 91-th order model is completed in 0.0590 seconds
# Computation for 92-th order model is completed in 0.1023 seconds
# Computation for 92-th order model is completed in 0.1194 seconds
# Computation for 92-th order model is completed in 0.1654 seconds
# Computation for 93-th order model is completed in 0.1167 seconds
# Computation for 93-th order model is completed in 0.1191 seconds
# Computation for 93-th order model is completed in 0.1225 seconds
# Computation for 94-th order model is completed in 0.1165 seconds
# Computation for 94-th order model is completed in 0.1780 seconds
# Computation for 94-th order model is completed in 0.1046 seconds
# Computation for 95-th order model is completed in 0.1154 seconds
# Computation for 95-th order model is completed in 0.1697 seconds
# Computation for 95-th order model is completed in 0.1152 seconds
# Computation for 96-th order model is completed in 0.1150 seconds
# Computation for 96-th order model is completed in 0.1746 seconds
# Computation for 96-th order model is completed in 0.1130 seconds
# Computation for 97-th order model is completed in 0.1683 seconds
# Computation for 97-th order model is completed in 0.1132 seconds
# Computation for 97-th order model is completed in 0.1152 seconds
# Computation for 98-th order model is completed in 0.1727 seconds
# Computation for 98-th order model is completed in 0.1116 seconds
# Computation for 98-th order model is completed in 0.1723 seconds
# Computation for 99-th order model is completed in 0.1189 seconds
# Computation for 99-th order model is completed in 0.1174 seconds
# Computation for 99-th order model is completed in 0.1697 seconds
# Computation for 100-th order model is completed in 0.1096 seconds
# Computation for 100-th order model is completed in 0.1182 seconds
# Computation for 100-th order model is completed in 0.1672 seconds
# Computation for 101-th order model is completed in 0.1084 seconds
# Computation for 101-th order model is completed in 0.1133 seconds
# Computation for 101-th order model is completed in 0.1651 seconds
# Computation for 102-th order model is completed in 0.1050 seconds
# Computation for 102-th order model is completed in 0.1252 seconds
# Computation for 102-th order model is completed in 0.1715 seconds
# Computation for 103-th order model is completed in 0.1066 seconds
# Computation for 103-th order model is completed in 0.1178 seconds
# Computation for 103-th order model is completed in 0.1725 seconds
# Computation for 104-th order model is completed in 0.1145 seconds
# Computation for 104-th order model is completed in 0.1150 seconds
# Computation for 104-th order model is completed in 0.1169 seconds
# Computation for 105-th order model is completed in 0.1174 seconds
# Computation for 105-th order model is completed in 0.1710 seconds
# Computation for 105-th order model is completed in 0.1194 seconds
# Computation for 106-th order model is completed in 0.1888 seconds
# Computation for 106-th order model is completed in 0.1780 seconds
# Computation for 106-th order model is completed in 0.1372 seconds
# Computation for 107-th order model is completed in 0.1885 seconds
# Computation for 107-th order model is completed in 0.1670 seconds
# Computation for 107-th order model is completed in 0.1346 seconds
# Computation for 108-th order model is completed in 0.1901 seconds
# /tmp/ipykernel_5128/1699435038.py:162: RuntimeWarning: overflow encountered in matmul
#   moment_i = (B_vec @ e) / (i * d)
# Computation for 108-th order model is completed in 0.1687 seconds
# Computation for 108-th order model is completed in 0.1351 seconds
# /tmp/ipykernel_5128/1699435038.py:161: RuntimeWarning: overflow encountered in matmul
#   B_vec = B_vec @ invA @ D1
# Computation for 109-th order model is completed in 0.1907 seconds
# Computation for 109-th order model is completed in 0.1809 seconds
# Computation for 109-th order model is completed in 0.1831 seconds
# Computation for 110-th order model is completed in 0.1354 seconds
# Computation for 110-th order model is completed in 0.1922 seconds
# Computation for 110-th order model is completed in 0.1674 seconds
# Computation for 111-th order model is completed in 0.1414 seconds
# Computation for 111-th order model is completed in 0.1886 seconds
# Computation for 111-th order model is completed in 0.1830 seconds
# Computation for 112-th order model is completed in 0.1868 seconds
# Computation for 112-th order model is completed in 0.1850 seconds
# Computation for 112-th order model is completed in 0.1417 seconds
# Computation for 113-th order model is completed in 0.1892 seconds
# Computation for 113-th order model is completed in 0.1771 seconds
# Computation for 113-th order model is completed in 0.1895 seconds
# Computation for 114-th order model is completed in 0.1854 seconds
# Computation for 114-th order model is completed in 0.1423 seconds
# Computation for 114-th order model is completed in 0.1822 seconds
# Computation for 115-th order model is completed in 0.1892 seconds
# Computation for 115-th order model is completed in 0.1893 seconds
# Computation for 115-th order model is completed in 0.1837 seconds
# Computation for 116-th order model is completed in 0.1481 seconds
# Computation for 116-th order model is completed in 0.1872 seconds
# Computation for 116-th order model is completed in 0.1706 seconds
# Computation for 117-th order model is completed in 0.1879 seconds
# Computation for 117-th order model is completed in 0.1895 seconds
# Computation for 117-th order model is completed in 0.1485 seconds
# Computation for 118-th order model is completed in 0.1874 seconds
# Computation for 118-th order model is completed in 0.1751 seconds
# Computation for 118-th order model is completed in 0.1830 seconds
# Computation for 119-th order model is completed in 0.1992 seconds
# Computation for 119-th order model is completed in 0.1949 seconds
# Computation for 119-th order model is completed in 0.1901 seconds
# Computation for 120-th order model is completed in 0.1498 seconds
# Computation for 120-th order model is completed in 0.1483 seconds
# Computation for 120-th order model is completed in 0.1907 seconds
# Computation for 121-th order model is completed in 0.1894 seconds
# Computation for 121-th order model is completed in 0.1828 seconds
# Computation for 121-th order model is completed in 0.1942 seconds
# Computation for 122-th order model is completed in 0.1904 seconds
# Computation for 122-th order model is completed in 0.1958 seconds
# Computation for 122-th order model is completed in 0.1925 seconds
# Computation for 123-th order model is completed in 0.1914 seconds
# Computation for 123-th order model is completed in 0.1994 seconds
# Computation for 123-th order model is completed in 0.1916 seconds
# Computation for 124-th order model is completed in 0.2080 seconds
# Computation for 124-th order model is completed in 0.2019 seconds
# Computation for 124-th order model is completed in 0.1990 seconds
# Computation for 125-th order model is completed in 0.2060 seconds
# Computation for 125-th order model is completed in 0.1895 seconds
# Computation for 125-th order model is completed in 0.1931 seconds
# Computation for 126-th order model is completed in 0.2003 seconds
# Computation for 126-th order model is completed in 0.1905 seconds
# Computation for 126-th order model is completed in 0.2042 seconds
# Computation for 127-th order model is completed in 0.1994 seconds
# Computation for 127-th order model is completed in 0.1933 seconds
# Computation for 127-th order model is completed in 0.1935 seconds
# Computation for 128-th order model is completed in 0.2026 seconds
# Computation for 128-th order model is completed in 0.2017 seconds
# Computation for 128-th order model is completed in 0.1836 seconds
# Computation for 129-th order model is completed in 0.2087 seconds
# Computation for 129-th order model is completed in 0.2163 seconds
# Computation for 129-th order model is completed in 0.1925 seconds
# Computation for 130-th order model is completed in 0.1868 seconds
# Computation for 130-th order model is completed in 0.1896 seconds
# Computation for 130-th order model is completed in 0.1880 seconds
# Computation for 131-th order model is completed in 0.2009 seconds
# Computation for 131-th order model is completed in 0.1934 seconds
# Computation for 131-th order model is completed in 0.2011 seconds
# Computation for 132-th order model is completed in 0.2107 seconds
# Computation for 132-th order model is completed in 0.2086 seconds
# Computation for 132-th order model is completed in 0.2052 seconds
# Computation for 133-th order model is completed in 0.2012 seconds
# Computation for 133-th order model is completed in 0.2017 seconds
# Computation for 133-th order model is completed in 0.1735 seconds
# Computation for 134-th order model is completed in 0.2071 seconds
# Computation for 134-th order model is completed in 0.2201 seconds
# Computation for 134-th order model is completed in 0.2227 seconds
# Computation for 135-th order model is completed in 0.2186 seconds
# Computation for 135-th order model is completed in 0.2111 seconds
# Computation for 135-th order model is completed in 0.2023 seconds
# Computation for 136-th order model is completed in 0.2242 seconds
# Computation for 136-th order model is completed in 0.2265 seconds
# Computation for 136-th order model is completed in 0.2222 seconds
# Computation for 137-th order model is completed in 0.2139 seconds
# Computation for 137-th order model is completed in 0.2280 seconds
# Computation for 137-th order model is completed in 0.2298 seconds
# Computation for 138-th order model is completed in 0.2210 seconds
# Computation for 138-th order model is completed in 0.2098 seconds
# Computation for 138-th order model is completed in 0.2029 seconds
# Computation for 139-th order model is completed in 0.2198 seconds
# Computation for 139-th order model is completed in 0.2415 seconds
# Computation for 139-th order model is completed in 0.2170 seconds
# Computation for 140-th order model is completed in 0.2250 seconds
# Computation for 140-th order model is completed in 0.2278 seconds
# Computation for 140-th order model is completed in 0.2115 seconds
# Computation for 141-th order model is completed in 0.2182 seconds
# Computation for 141-th order model is completed in 0.2324 seconds
# Computation for 141-th order model is completed in 0.2473 seconds
# Computation for 142-th order model is completed in 0.2317 seconds
# Computation for 142-th order model is completed in 0.2378 seconds
# Computation for 142-th order model is completed in 0.2261 seconds
# Computation for 143-th order model is completed in 0.2447 seconds
# Computation for 143-th order model is completed in 0.2523 seconds
# Computation for 143-th order model is completed in 0.2413 seconds
# Computation for 144-th order model is completed in 0.2407 seconds
# Computation for 144-th order model is completed in 0.2388 seconds
# Computation for 144-th order model is completed in 0.2553 seconds
# Computation for 145-th order model is completed in 0.2373 seconds
# Computation for 145-th order model is completed in 0.2585 seconds
# Computation for 145-th order model is completed in 0.2377 seconds
# Computation for 146-th order model is completed in 0.2543 seconds
# Computation for 146-th order model is completed in 0.2440 seconds
# Computation for 146-th order model is completed in 0.2462 seconds
# Computation for 147-th order model is completed in 0.2500 seconds
# Computation for 147-th order model is completed in 0.2476 seconds
# Computation for 147-th order model is completed in 0.2480 seconds
# Computation for 148-th order model is completed in 0.2500 seconds
# Computation for 148-th order model is completed in 0.2503 seconds
# Computation for 148-th order model is completed in 0.2488 seconds
# Computation for 149-th order model is completed in 0.2476 seconds
# Computation for 149-th order model is completed in 0.2443 seconds
# Computation for 149-th order model is completed in 0.2468 seconds
# Computation for 150-th order model is completed in 0.2528 seconds
# Computation for 150-th order model is completed in 0.2519 seconds
# Computation for 150-th order model is completed in 0.2352 seconds
# Computation for 151-th order model is completed in 0.2620 seconds
# Computation for 151-th order model is completed in 0.2473 seconds
# Computation for 151-th order model is completed in 0.2582 seconds
# Computation for 152-th order model is completed in 0.2570 seconds
# Computation for 152-th order model is completed in 0.2600 seconds
# Computation for 152-th order model is completed in 0.2588 seconds
# Computation for 153-th order model is completed in 0.2420 seconds
# Computation for 153-th order model is completed in 0.2584 seconds
# Computation for 153-th order model is completed in 0.2603 seconds
# Computation for 154-th order model is completed in 0.2544 seconds
# Computation for 154-th order model is completed in 0.2673 seconds
# Computation for 154-th order model is completed in 0.2460 seconds
# Computation for 155-th order model is completed in 0.2674 seconds
# Computation for 155-th order model is completed in 0.2651 seconds
# Computation for 155-th order model is completed in 0.2565 seconds
# Computation for 156-th order model is completed in 0.2695 seconds
# Computation for 156-th order model is completed in 0.2685 seconds
# Computation for 156-th order model is completed in 0.2622 seconds
# Computation for 157-th order model is completed in 0.2630 seconds
# Computation for 157-th order model is completed in 0.2937 seconds
# Computation for 157-th order model is completed in 0.2855 seconds
# Computation for 158-th order model is completed in 0.2657 seconds
# Computation for 158-th order model is completed in 0.2627 seconds
# Computation for 158-th order model is completed in 0.2567 seconds
# Computation for 159-th order model is completed in 0.2684 seconds
# Computation for 159-th order model is completed in 0.2693 seconds
# Computation for 159-th order model is completed in 0.2417 seconds
# Computation for 160-th order model is completed in 0.2867 seconds
# Computation for 160-th order model is completed in 0.2862 seconds
# Computation for 160-th order model is completed in 0.2660 seconds
# Computation for 161-th order model is completed in 0.2420 seconds
# Computation for 161-th order model is completed in 0.2797 seconds
# Computation for 161-th order model is completed in 0.2697 seconds
# Computation for 162-th order model is completed in 0.2537 seconds
# Computation for 162-th order model is completed in 0.2516 seconds
# Computation for 162-th order model is completed in 0.2490 seconds
# Computation for 163-th order model is completed in 0.2530 seconds
# Computation for 163-th order model is completed in 0.2790 seconds
# Computation for 163-th order model is completed in 0.2588 seconds
# Computation for 164-th order model is completed in 0.2523 seconds
# Computation for 164-th order model is completed in 0.2873 seconds
# Computation for 164-th order model is completed in 0.3078 seconds
# Computation for 165-th order model is completed in 0.3127 seconds
# Computation for 165-th order model is completed in 0.3049 seconds
# Computation for 165-th order model is completed in 0.3102 seconds
# Computation for 166-th order model is completed in 0.2919 seconds
# Computation for 166-th order model is completed in 0.2945 seconds
# Computation for 166-th order model is completed in 0.2886 seconds
# Computation for 167-th order model is completed in 0.2936 seconds
# Computation for 167-th order model is completed in 0.2928 seconds
# Computation for 167-th order model is completed in 0.2615 seconds
# Computation for 168-th order model is completed in 0.2714 seconds
# Computation for 168-th order model is completed in 0.2823 seconds
# Computation for 168-th order model is completed in 0.2665 seconds
# Computation for 169-th order model is completed in 0.2784 seconds
# Computation for 169-th order model is completed in 0.2826 seconds
# Computation for 169-th order model is completed in 0.2837 seconds
# Computation for 170-th order model is completed in 0.2938 seconds
# Computation for 170-th order model is completed in 0.3190 seconds
# Computation for 170-th order model is completed in 0.2832 seconds
# Computation for 171-th order model is completed in 0.2965 seconds
# Computation for 171-th order model is completed in 0.3091 seconds
# Computation for 171-th order model is completed in 0.2800 seconds
# Computation for 172-th order model is completed in 0.2893 seconds
# Computation for 172-th order model is completed in 0.2798 seconds
# Computation for 172-th order model is completed in 0.2662 seconds
# Computation for 173-th order model is completed in 0.2605 seconds
# Computation for 173-th order model is completed in 0.2458 seconds
# Computation for 173-th order model is completed in 0.2617 seconds
# Computation for 174-th order model is completed in 0.2472 seconds
# Computation for 174-th order model is completed in 0.2590 seconds
# Computation for 174-th order model is completed in 0.2624 seconds
# Computation for 175-th order model is completed in 0.2638 seconds
# Computation for 175-th order model is completed in 0.2690 seconds
# Computation for 175-th order model is completed in 0.2614 seconds
# Computation for 176-th order model is completed in 0.2548 seconds
# Computation for 176-th order model is completed in 0.2683 seconds
# Computation for 176-th order model is completed in 0.2722 seconds
# Computation for 177-th order model is completed in 0.2579 seconds
# Computation for 177-th order model is completed in 0.2593 seconds
# Computation for 177-th order model is completed in 0.2780 seconds
# Computation for 178-th order model is completed in 0.2681 seconds
# Computation for 178-th order model is completed in 0.2508 seconds
# Computation for 178-th order model is completed in 0.2709 seconds
# Computation for 179-th order model is completed in 0.2725 seconds
# Computation for 179-th order model is completed in 0.2625 seconds
# Computation for 179-th order model is completed in 0.2599 seconds
# Computation for 180-th order model is completed in 0.2812 seconds
# Computation for 180-th order model is completed in 0.2698 seconds
# Computation for 180-th order model is completed in 0.2633 seconds
# Computation for 181-th order model is completed in 0.2778 seconds
# Computation for 181-th order model is completed in 0.2888 seconds
# Computation for 181-th order model is completed in 0.2756 seconds
# Computation for 182-th order model is completed in 0.2685 seconds
# Computation for 182-th order model is completed in 0.2721 seconds
# Computation for 182-th order model is completed in 0.2560 seconds
# Computation for 183-th order model is completed in 0.2811 seconds
# Computation for 183-th order model is completed in 0.3030 seconds
# Computation for 183-th order model is completed in 0.2891 seconds
# Computation for 184-th order model is completed in 0.2889 seconds
# Computation for 184-th order model is completed in 0.2852 seconds
# Computation for 184-th order model is completed in 0.2827 seconds
# Computation for 185-th order model is completed in 0.2849 seconds
# Computation for 185-th order model is completed in 0.2730 seconds
# Computation for 185-th order model is completed in 0.2793 seconds
# Computation for 186-th order model is completed in 0.2874 seconds
# Computation for 186-th order model is completed in 0.2791 seconds
# Computation for 186-th order model is completed in 0.2892 seconds
# Computation for 187-th order model is completed in 0.3184 seconds
# Computation for 187-th order model is completed in 0.2861 seconds
# Computation for 187-th order model is completed in 0.2767 seconds
# Computation for 188-th order model is completed in 0.2993 seconds
# Computation for 188-th order model is completed in 0.3014 seconds
# Computation for 188-th order model is completed in 0.2882 seconds
# Computation for 189-th order model is completed in 0.3087 seconds
# Computation for 189-th order model is completed in 0.3005 seconds
# Computation for 189-th order model is completed in 0.2787 seconds
# Computation for 190-th order model is completed in 0.3041 seconds
# Computation for 190-th order model is completed in 0.3002 seconds
# Computation for 190-th order model is completed in 0.2907 seconds
# Computation for 191-th order model is completed in 0.2961 seconds
# Computation for 191-th order model is completed in 0.2949 seconds
# Computation for 191-th order model is completed in 0.2957 seconds
# Computation for 192-th order model is completed in 0.2952 seconds
# Computation for 192-th order model is completed in 0.3114 seconds
# Computation for 192-th order model is completed in 0.3090 seconds
# Computation for 193-th order model is completed in 0.3199 seconds
# Computation for 193-th order model is completed in 0.3325 seconds
# Computation for 193-th order model is completed in 0.3100 seconds
# Computation for 194-th order model is completed in 0.3256 seconds
# Computation for 194-th order model is completed in 0.3303 seconds
# Computation for 194-th order model is completed in 0.3138 seconds
# Computation for 195-th order model is completed in 0.3159 seconds
# Computation for 195-th order model is completed in 0.3272 seconds
# Computation for 195-th order model is completed in 0.3377 seconds
# Computation for 196-th order model is completed in 0.3112 seconds
# Computation for 196-th order model is completed in 0.3254 seconds
# Computation for 196-th order model is completed in 0.3356 seconds
# Computation for 197-th order model is completed in 0.3175 seconds
# Computation for 197-th order model is completed in 0.3433 seconds
# Computation for 197-th order model is completed in 0.3354 seconds
# Computation for 198-th order model is completed in 0.3316 seconds
# Computation for 198-th order model is completed in 0.3490 seconds
# Computation for 198-th order model is completed in 0.3107 seconds
# Computation for 199-th order model is completed in 0.3338 seconds
# Computation for 199-th order model is completed in 0.3412 seconds
# Computation for 199-th order model is completed in 0.3221 seconds
# Computation for 200-th order model is completed in 0.3458 seconds
# Computation for 200-th order model is completed in 0.3387 seconds
# Computation for 200-th order model is completed in 0.3416 seconds

# %%
# Save the results in a `.npy` file
# np.save('Main_times.npy', times)

# %%
# load .npy file
loaded_array = np.load('Main_times.npy')
loaded_list_from_array = loaded_array.tolist()
print(loaded_list_from_array)
# Out:
# [0.017479340235392254, 0.010891199111938477, 0.007544994354248047, 0.006255388259887695, 0.005748589833577474, 0.0054627259572347, 0.005471229553222656, 0.005526622136433919, 0.00612489382425944, 0.0066649119059244795, 0.006467342376708984, 0.006778319676717122, 0.00565338134765625, 0.005725542704264323, 0.005891879399617513, 0.005863030751546224, 0.006070693333943685, 0.006250063578287761, 0.006417671839396159, 0.006469249725341797, 0.006787220637003581, 0.006890535354614258, 0.007974942525227865, 0.007248481114705403, 0.007611274719238281, 0.007734060287475586, 0.008041620254516602, 0.008054574330647787, 0.008403778076171875, 0.008725722630818685, 0.00958720842997233, 0.008910338083902994, 0.009437640508015951, 0.009612798690795898, 0.010058164596557617, 0.01019446055094401, 0.010800758997599283, 0.011470953623453775, 0.011380354563395182, 0.011371771494547525, 0.012075980504353842, 0.012183745702107748, 0.013129234313964844, 0.012829860051472982, 0.013636191685994467, 0.0136777559
# ...
